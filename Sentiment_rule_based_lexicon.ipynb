# %% [markdown]
# <a href="https://colab.research.google.com/github/tanusreeg/awesome-for-beginners/blob/master/Sentiment_rule_based_lexicon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 5.9MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

consumer_key = 'KQUUVp7X6B5ZSwbMdDi8c3OnD'
consumer_secret = '04f0RdCKISUAjfXT9A7PbRVnYTJoyXcWTWd5nP0dgH3WxQQyQd'
access_token = '781984344-PchmTjil7tSusZfe42iZXpYV9L0z01JMQdz8a6V8'
access_token_secret = 'QGLeV3Q1f36R8gt3NFZzIoZz1ejdwAB0p82tf3ebAWkLA'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('URI', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @MrsGandhi: Surgical strike in Bengal by Mo...
# 1  @issoubaby 😅 entre toi et moi qui date mdr. C’...
# 2  RT @MrsGandhi: Surgical strike in Bengal by Mo...
# 3  @MartinLedesmaPR No dije que fueron un funeral...
# 4  RT @5thYear: URI seems like they handled the P...
# 5  RT @NYCDEATHROWCATS: Orange creamsicle needs y...
# 6  La re concha puta de tu puta madre periodismo ...
# 7                  @uri_tatsumi @n_aihara おはようごさいます！
# 8  @lililili0305 情報ありがとうございます🙇\nなんで今日こんなに多いんですかね。...
# 9  RT @iMac_too: Congress hopes to recreate Uri's...
# 2019-02-04 21:03:10

# %%
import nltk
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#                                                Tweets  \
# 0   RT @MrsGandhi: Surgical strike in Bengal by Mo...
# 1   @issoubaby 😅 entre toi et moi qui date mdr. C’...
# 2   RT @MrsGandhi: Surgical strike in Bengal by Mo...
# 3   @MartinLedesmaPR No dije que fueron un funeral...
# 4   RT @5thYear: URI seems like they handled the P...
# 5   RT @NYCDEATHROWCATS: Orange creamsicle needs y...
# 6   La re concha puta de tu puta madre periodismo ...
# 7                   @uri_tatsumi @n_aihara おはようごさいます！
# 8   @lililili0305 情報ありがとうございます🙇\nなんで今日こんなに多いんですかね。...
# 9   RT @iMac_too: Congress hopes to recreate Uri's...
# 10  RT @AKrisnapriya: surgical strike in Bengal by...
# 11  @Uri_grana Jajaj yo también estuve ahí y  estu...
# 12  RT @prasannavishy: The Josh Remains High: Uri ...
# 13  RT @ko1529: わたこうと夜の街を放浪してる https://t.co/ElTxob...
# 14  RT @btsforarmy_ina: Ga tau kenapa masih suka m...
# ...
